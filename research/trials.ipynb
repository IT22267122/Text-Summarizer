# %%
d={"key":  "value","key2":  "value2","key3":  "value3"}

# %%
d['key']
# Out:
# 'value'

# %%
pip install python-box
# Out:
# Collecting python-box
#   Downloading python_box-7.2.0-cp310-cp310-win_amd64.whl (1.2 MB)
#      ---------------------------------------- 1.2/1.2 MB 487.7 kB/s eta 0:00:00
# Installing collected packages: python-box
# Successfully installed python-box-7.2.0
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (d:\python3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\python3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\python3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\python3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\python3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\python3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\python3\lib\site-packages)
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the 'd:\python3\python.exe -m pip install --upgrade pip' command.

# %%
from box import ConfigBox

# %%
d2=ConfigBox({"key":  "value","key2":  "value2","key3":  "value3"})

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'key2': 'value2', 'key3': 'value3'})

# %%
d2.key
# Out:
# 'value'

# %%
def get_product(x:int,y:int)->int:
    return x*y

# %%
get_product(2,4)
# Out:
# 8

# %%
get_product(2,"4")
# Out:
# '44'

# %%
pip install ensure
# Out:
# Requirement already satisfied: ensure in d:\python3\lib\site-packages (1.0.4)
# Requirement already satisfied: six>=1.11.0 in d:\python3\lib\site-packages (from ensure) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -ip (d:\python3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\python3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\python3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\python3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\python3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ip (d:\python3\lib\site-packages)
# WARNING: You are using pip version 22.0.4; however, version 24.2 is available.
# You should consider upgrading via the 'd:\python3\python.exe -m pip install --upgrade pip' command.

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int,y:int)->int:
    return x*y

# %%
get_product(2,"4")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 get_product(2,"4")
#
# File d:\python3\lib\site-packages\ensure\main.py:870, in WrappedFunctionReturn.__call__(self, *args, **kwargs)
#     868     if not isinstance(value, templ):
#     869         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 870         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     872 return_val = self.f(*args, **kwargs)
#     873 if not isinstance(return_val, self.return_templ):
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x000001AD2391C3A0> does not match annotation type <class 'int'>

# %%
get_product(2,4)
# Out:
# 8
